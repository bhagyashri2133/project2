# %%
# ! pip install indic_transliteration

# %%
# Transliteration
Syntax : transliterate(text, romanization_style, script)

Parameters :
test : The text totransliterated
romanization_style : The following romanization styles are available :

HK = ‘hk’
IAST = ‘iast’ (International Alphabet of Sanskrit Transliteration)
ITRANS = ‘itrans’ (Indian languages TRANSliteration)
OPTITRANS = ‘optitrans’
KOLKATA = ‘kolkata’
SLP1 = ‘slp1’
VELTHUIS = ‘velthuis’
WX = ‘wx’
script : The script to be transliterated into. The following scripts are available :

Bengali
Devanagari
Gujarati
Kannada
Malayalam
Telugu
Tamil
Oriya
Gurmukhi/ Punjabi/ Panjabi

# %%
# language translation
from googletrans import Translator
def lang_trans(data):
    translor = Translator()
    translated_text = translor.translate(data)
    return translated_text.text

# %%
from indic_transliteration import sanscript
from indic_transliteration.sanscript import transliterate

# %%
text = "Aap kya kar rahe ho?"
print(transliterate(text,sanscript.ITRANS,sanscript.DEVANAGARI))
# Out:
# आअप् क्य कर् रहे हो?

# %%
lang_trans('आअप् क्य कर् रहे हो ')
# Out:
# 'what are you doing'

# %%
text = "Tu kashi ahes"
print(transliterate(text,sanscript.ITRANS,sanscript.DEVANAGARI))
# Out:
# टु कशि अहेस्

# %%
lang_trans('टु कशि अहेस्')
# Out:
# 'how are you'

# %%
text = "Suprabhaata"
print(transliterate(text,sanscript.ITRANS,sanscript.GUJARATI))
# Out:
# ષુપ્રભાત

# %%
lang_trans('ષુપ્રભાત')
# Out:
# 'good morning'

# %%
text = "Suprabhaata"
print(transliterate(text,sanscript.ITRANS,sanscript.TELUGU))
# Out:
# షుప్రభాత

# %%
text = "Suprabhaata"
print(transliterate(text,sanscript.ITRANS,sanscript.TAMIL))
# Out:
# ஷுப்ரபாத

# %%
text = "Suprabhaata"
print(transliterate(text,sanscript.ITRANS,sanscript.ORIYA))
# Out:
# ଷୁପ୍ରଭାତ

# %%
text = "Suprabhaata"
print(transliterate(text,sanscript.ITRANS,sanscript.BENGALI))
# Out:
# ষুপ্রভাত

# %%
text = "Suprabhaata"
print(transliterate(text,sanscript.ITRANS,sanscript.MALAYALAM))
# Out:
# ഷുപ്രഭാത
